# %% [markdown]
# # Laboratory Exercise 1: Introduction to Google Earth Engine (GEE)
# In this lab, you will learn how to initialize Google Earth Engine (GEE), select satellite images, visualize data, and analyze basic metadata.

# %%
import ee
ee.Authenticate()
ee.Initialize(project='ee-kacperkrempa01')

# %% [markdown]
# ## Task 2: Define Area of Interest (AOI)
# Define your area of interest (AOI). You can use either a point or a bounding box.
# Example coordinates are provided below (Krakow, Poland). Adjust them for your location.

# %%
# Define AOI
# TODO: Replace with your coordinates
aoi = ee.Geometry.Point([20.0164, 40.0203])  # Example: Albania
# or
# aoi = ee.Geometry.Rectangle([west, south, east, north])

# %% [markdown]
# ## Task 3: Retrieve Sentinel-2 Data
# Retrieve Sentinel-2 imagery for your defined AOI within a specific date range. Sort the images based on cloud cover percentage.

# %%
# Retrieve Sentinel-2 Data
sentinel2 = ee.ImageCollection('COPERNICUS/S2_HARMONIZED') \
    .filterDate('2024-07-01', '2024-08-01') \
    .filterBounds(aoi) \
    .sort('CLOUDY_PIXEL_PERCENTAGE')

image = sentinel2.first()
image.getInfo()
# Out:
# {'type': 'Image',
#  'bands': [{'id': 'B1',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32634',
#    'crs_transform': [60, 0, 399960, 0, -60, 4500000]},
#   {'id': 'B2',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32634',
#    'crs_transform': [10, 0, 399960, 0, -10, 4500000]},
#   {'id': 'B3',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32634',
#    'crs_transform': [10, 0, 399960, 0, -10, 4500000]},
#   {'id': 'B4',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32634',
#    'crs_transform': [10, 0, 399960, 0, -10, 4500000]},
#   {'id': 'B5',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32634',
#    'crs_transform': [20, 0, 399960, 0, -20, 4500000]},
#   {'id': 'B6',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32634',
#    'crs_transform': [20, 0, 399960, 0, -20, 4500000]},
#   {'id': 'B7',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32634',
#    'crs_transform': [20, 0, 399960, 0, -20, 4500000]},
#   {'id': 'B8',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32634',
#    'crs_transform': [10, 0, 399960, 0, -10, 4500000]},
#   {'id': 'B8A',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32634',
#    'crs_transform': [20, 0, 399960, 0, -20, 4500000]},
#   {'id': 'B9',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32634',
#    'crs_transform': [60, 0, 399960, 0, -60, 4500000]},
#   {'id': 'B10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32634',
#    'crs_transform': [60, 0, 399960, 0, -60, 4500000]},
#   {'id': 'B11',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32634',
#    'crs_transform': [20, 0, 399960, 0, -20, 4500000]},
#   {'id': 'B12',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32634',
#    'crs_transform': [20, 0, 399960, 0, -20, 4500000]},
#   {'id': 'QA10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'QA20',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 4294967295},
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'QA60',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32634',
#    'crs_transform': [60, 0, 399960, 0, -60, 4500000]},
#   {'id': 'MSK_CLASSI_OPAQUE',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32634',
#    'crs_transform': [60, 0, 399960, 0, -60, 4500000]},
#   {'id': 'MSK_CLASSI_CIRRUS',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32634',
#    'crs_transform': [60, 0, 399960, 0, -60, 4500000]},
#   {'id': 'MSK_CLASSI_SNOW_ICE',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32634',
#    'crs_transform': [60, 0, 399960, 0, -60, 4500000]}],
#  'version': 1742421533803542,
#  'id': 'COPERNICUS/S2_HARMONIZED/20240729T092549_20240729T092855_T34TDK',
#  'properties': {'DATATAKE_IDENTIFIER': 'GS2B_20240729T092549_038629_N05.11',
#   'SPACECRAFT_NAME': 'Sentinel-2B',
#   'RADIO_ADD_OFFSET_B8A': -1000,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 250.716229193015,
#   'RADIO_ADD_OFFSET_B10': -1000,
#   'MEAN_SOLAR_AZIMUTH_ANGLE': 142.244660330759,
#   'system:footprint': {'type': 'LinearRing',
#    'coordinates': [[19.83385214148921, 39.65584332085262],
#     [19.833866767274884, 39.65584277343972],
#     [21.11354686791389, 39.66164169220781],
#     [21.113600809634793, 39.66167822830095],
#     [21.113660300168323, 39.66170919268941],
#     [21.11366393873311, 39.66172401712517],
#     [21.115325126123935, 40.650798965278376],
#     [21.115277006068403, 40.65084045459694],
#     [21.115236072184562, 40.65088620339263],
#     [21.115216605848964, 40.65088902972874],
#     [19.81682578240714, 40.64488479960895],
#     [19.816771822931884, 40.64484762425036],
#     [19.816712140487528, 40.64481593802486],
#     [19.81670868853506, 40.644801131464135],
#     [19.825333997509002, 40.150384495049124],
#     [19.833748398348586, 39.65593159770929],
#     [19.83379663618151, 39.655890564240536],
#     [19.833837788234035, 39.65584525869681],
#     [19.83385214148921, 39.65584332085262]]},
#   'SOLAR_IRRADIANCE_B12': 87.75,
#   'SOLAR_IRRADIANCE_B10': 365.41,
#   'SENSOR_QUALITY': 'PASSED',
#   'SOLAR_IRRADIANCE_B11': 247.08,
#   'GENERATION_TIME': 1722248563000,
#   'RADIO_ADD_OFFSET_B12': -1000,
#   'RADIO_ADD_OFFSET_B11': -1000,
#   'SOLAR_IRRADIANCE_B8A': 953.93,
#   'FORMAT_CORRECTNESS': 'PASSED',
#   'CLOUD_COVERAGE_ASSESSMENT': 0.006718624026,
#   'system:time_end': 1722245966825,
#   'SNOW_PIXEL_PERCENTAGE': 0,
#   'system:time_start': 1722245966825,
#   'RADIO_ADD_OFFSET_B1': -1000,
#   'RADIO_ADD_OFFSET_B2': -1000,
#   'DATASTRIP_ID': 'S2B_OPER_MSI_L1C_DS_2BPS_20240729T102243_S20240729T092855_N05.11',
#   'RADIO_ADD_OFFSET_B3': -1000,
#   'RADIO_ADD_OFFSET_B4': -1000,
#   'RADIO_ADD_OFFSET_B5': -1000,
#   'PROCESSING_BASELINE': '05.11',
#   'SENSING_ORBIT_NUMBER': 136,
#   'RADIO_ADD_OFFSET_B6': -1000,
#   'RADIO_ADD_OFFSET_B7': -1000,
#   'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#   'GENERAL_QUALITY': 'PASSED',
#   'GRANULE_ID': 'L1C_T34TDK_A038629_20240729T092855',
#   'REFLECTANCE_CONVERSION_CORRECTION': 0.969405906015082,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 253.361676458104,
#   'DATATAKE_TYPE': 'INS-NOBS',
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 250.294978683322,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 250.894937217687,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 250.776904431148,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 251.630606604473,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 4.38616609092363,
#   'RADIO_ADD_OFFSET_B8': -1000,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 251.268182302771,
#   'RADIOMETRIC_QUALITY': 'PASSED',
#   'RADIO_ADD_OFFSET_B9': -1000,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 254.454265663553,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 252.589892286481,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 4.10987689199278,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 250.369503411424,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 4.0509500225136,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 3.95383394908934,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 3.87070667668008,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 4.46392898313241,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 3.90783364967365,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 4.24237407911082,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 4.17618710087686,
#   'MEAN_SOLAR_ZENITH_ANGLE': 25.727735975267,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 4.31839642091386,
#   'MGRS_TILE': '34TDK',
#   'CLOUDY_PIXEL_PERCENTAGE': 0.00671862402579952,
#   'PRODUCT_ID': 'S2B_MSIL1C_20240729T092549_N0511_R136_T34TDK_20240729T102243',
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 4.03077363323598,
#   'SOLAR_IRRADIANCE_B9': 817.58,
#   'DEGRADED_MSI_DATA_PERCENTAGE': 0.0064,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 4.17162210032912,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 4.33969352135591,
#   'SOLAR_IRRADIANCE_B6': 1291.13,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 251.745854647614,
#   'SOLAR_IRRADIANCE_B5': 1425.78,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 251.029077387738,
#   'SOLAR_IRRADIANCE_B8': 1041.28,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 250.700178077428,
#   'SOLAR_IRRADIANCE_B7': 1175.57,
#   'SOLAR_IRRADIANCE_B2': 1959.75,
#   'SOLAR_IRRADIANCE_B1': 1874.3,
#   'SOLAR_IRRADIANCE_B4': 1512.79,
#   'GEOMETRIC_QUALITY': 'PASSED',
#   'SOLAR_IRRADIANCE_B3': 1824.93,
#   'system:asset_size': 1301840974,
#   'system:index': '20240729T092549_20240729T092855_T34TDK'}}

# %% [markdown]
# ## Task 4: Extract Image Metadata
# Extract and print metadata from the selected image, such as ID, cloud cover percentage, mean solar azimuth and zenith angles, and processing level.

# %%
# Extract metadata
# TODO: Retrieve and display image metadata
metadata = {
    "Cloud coverage assessment" : image.get('CLOUD_COVERAGE_ASSESSMENT').getInfo(),
    " Mean solar zenith angle" : image.get('MEAN_SOLAR_ZENITH_ANGLE').getInfo(),
    "Mean solar azimuth angle:" : image.get('MEAN_SOLAR_AZIMUTH_ANGLE').getInfo(),
    "Processing baseline:" : image.get('PROCESSING_BASELINE').getInfo()
}
print(metadata)
# Out:
# {'Cloud coverage assessment': 0.006718624026, ' Mean solar zenith angle': 25.727735975267, 'Mean solar azimuth angle:': 142.244660330759, 'Processing baseline:': '05.11'}

# %% [markdown]
# ## Task 5: Visualize Image
# Create a map and visualize the Sentinel-2 image using different visualization parameters (e.g., true color, false color).

# %%
import geemap
# Visualization
# TODO: Create visualization layers using true color and false color compositions
# Example parameters provided below:
Map = geemap.Map()
true_color_params = {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 3000}
false_color_params = {'bands': ['B8', 'B4', 'B3'], 'min': 0, 'max': 5000}
Map.addLayer(image, true_color_params, "True color")
Map.addLayer(image, false_color_params, "False color")
Map.centerObject(image, zoom=12)
# TODO: Add these layers to an interactive map

Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[40.15509664050596, 20.469885592092172], controls=(WidgetControl(options=['position', 'transparent_…

# %% [markdown]
# ## Submission
# Save your completed notebook and submit it to your course repository.
